# %%
from pymongo.mongo_client import MongoClient
import pandas as pd
import json

# %%
# uniform resource indentifier
uri = "mongodb+srv://user:pass@cluster0.0iyu8a9.mongodb.net/?retryWrites=true&w=majority"

# Create a new client and connect to the server
client = MongoClient(uri)

# %%
DATABASE_NAME="ML"
COLLECTION_NAME="credit_card"

# %%
df=pd.read_csv(r"C:\Users\pnavn\Downloads\credit-card-fraud-detection-main\credit-card-fraud-detection-main\notebooks\creditCardFraud_28011964_120214.csv")

# %%
df.head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0      50000    1          2         1   57     -1      0     -1      0
# 1      50000    1          1         2   37      0      0      0      0
# 2     500000    1          1         2   29      0      0      0      0
# 3     100000    2          2         2   23      0     -1     -1      0
# 4     140000    2          3         1   28      0      0      2      0
#
#    PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0      0  ...      20940      19146      19131      2000     36681     10000
# 1      0  ...      19394      19619      20024      2500      1815       657
# 2      0  ...     542653     483003     473944     55000     40000     38000
# 3      0  ...        221       -159        567       380       601         0
# 4      0  ...      12211      11793       3719      3329         0       432
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
# Convert the data into json
json_record=list(json.loads(df.T.to_json()).values())

# %%
client[DATABASE_NAME][COLLECTION_NAME].insert_many(json_record)
